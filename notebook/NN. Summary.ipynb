# %%
# ============================================================
# Notebook setup
# ============================================================

# %load_ext autoreload
# %autoreload 2

figsize=(14, 4)

from utils import DataAggregator
import utils.data_visualizator as utils_dv
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_aggregator = DataAggregator()

# %% [markdown]
# # Summary

# %%
metrics = data_aggregator.read_metrics()

# %%
metrics
# Out:
#                      Accuracy   Profit
# Model
# baseline             0.358294 -4895.83
# odds                 0.209005 -5946.89
# ELO-model-1          0.510526    -9.70
# ELO-model-2          0.515789    89.90
# optimized-ELO-model  0.542105   283.60
# dt-classifier        0.663158  8558.80
# nb-classifier        0.626316  8144.30
# lp-classifier        0.355263  1859.00
# svc-classifier       0.684211  8544.80
# knn-classifier       0.531579  6952.70
# adb-classifier       0.650000  8449.70
# rf-classifier        0.660526  8481.70

# %%
utils_dv.plot_metrics(metrics)
