# %%
# ============================================================
# Notebook setup
# ============================================================

# %load_ext autoreload
# %autoreload 2

figsize=(14, 4)

from utils import DataAggregator
import utils.data_visualizator as utils_dv
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_aggregator = DataAggregator()

# %% [markdown]
# # Summary

# %%
metrics = data_aggregator.read_metrics()

# %%
metrics
# Out:
#                            Accuracy   Profit
# Model
# baseline                   0.358294 -4895.83
# odds                       0.209005 -5946.89
# ELO-model-1                0.510526    -9.70
# ELO-model-2                0.515789    89.90
# optimized-ELO-model        0.542105   283.60
# dt-classifier              0.597368  7906.60
# nb-classifier              0.573684  7498.50
# lp-classifier              0.215789  -591.00
# svc-classifier             0.615789  7887.80
# knn-classifier             0.502632  6244.00
# adb-classifier             0.636842  8231.00
# rf-classifier              0.631579  8200.00
# nn_cls                     0.626316  7791.50
# nn_regr                    0.457895  5861.80
# adb-classifier (no draws)  0.805369  8939.40

# %%
utils_dv.plot_metrics(metrics)
